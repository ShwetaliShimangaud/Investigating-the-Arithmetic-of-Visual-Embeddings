# %%
# !pip install bing-image-downloader

# %%
# !mkdir images

# %%
from bing_image_downloader import downloader
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
for i in df['pair2'][:50]:
    first_word = i.split(':')[0]
    downloader.download("feet unit",limit=30,output_dir='images')
# Out:
# [%] Downloading Images to /Users/rishabhthaney/Documents/McGill/545/Project/Investigating-the-Arithmetic-of-Visual-Embeddings/images/feet unit
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 30 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://1.bp.blogspot.com/_U_KzC7i272c/TQW04tMPkGI/AAAAAAAAAjo/ZYrqcOw6rzI/s1600/171.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://4.bp.blogspot.com/_U_KzC7i272c/TQd7z-8jFpI/AAAAAAAAAmA/BVdnAVvHfvw/s1600/202.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://2.bp.blogspot.com/_U_KzC7i272c/TPErkDEGS1I/AAAAAAAAAYQ/cmwf0nzWI7A/s1600/95.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://3.bp.blogspot.com/_U_KzC7i272c/TQW3GMfnOLI/AAAAAAAAAj4/0eJprctjZD4/s1600/173.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://optimizehealth365.com/wp-content/uploads/2020/05/Depositphotos_115173618_s-2019.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download("crown",limit=15,output_dir='images')
# Out:
# [%] Downloading Images to /Users/rishabhthaney/Documents/McGill/545/Project/Investigating-the-Arithmetic-of-Visual-Embeddings/images/crown
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 15 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://upload.wikimedia.org/wikipedia/commons/7/7f/Royal_crown_of_Sweden.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://live.staticflickr.com/5022/5809944700_3d715abe88_b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://upload.wikimedia.org/wikipedia/commons/f/fc/Crown_jewels_Poland_10.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://theenchantedmanor.com/wp-content/uploads/2013/09/Imperial-Crown-of-India.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://cliparts.co/cliparts/pi5/rkb/pi5rkbM5T.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://i.etsystatic.com/19451043/r/il/2deef3/1770422760/il_1140xN.1770422760_ejx3.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download("penetrated chemistry",limit=30,output_dir='images',adult_filter_off=False)
# Out:
# [%] Downloading Images to /Users/rishabhthaney/Documents/McGill/545/Project/Investigating-the-Arithmetic-of-Visual-Embeddings/images/penetrated chemistry
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 30 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://pubs.rsc.org/en/Image/Get?imageInfo.ImageType=GA&amp;imageInfo.ImageIdentifier.ManuscriptID=C7SC04192F&amp;imageInfo.ImageIdentifier.Year=2018
# [!] Issue getting: https://pubs.rsc.org/en/Image/Get?imageInfo.ImageType=GA&amp;imageInfo.ImageIdentifier.ManuscriptID=C7SC04192F&amp;imageInfo.ImageIdentifier.Year=2018
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #1 from https://xpic.x-mol.com/20211007/10.1039_D1TA06514A.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://xpic.x-mol.com/20230908/10.1021_acs.analchem.3c01505.jpg
# [%] File Downloaded !
#
# ...

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from scipy.stats import spearmanr, zscore

# %%
df = pd.read_csv('data_3.csv')

# %%
df['diff_cos_before_normalization'] = df['cos_image_before_normalization'] - df['cos_text_before_normalization']
df.to_csv('data_3.csv', index=False)

# %%
df['diff_rho_before_normalization'] = df['rho_image_before_normalization'] - df['rho_text_before_normalization']
df['diff_cos_after_normalization'] = df['cos_image_after_normalization'] - df['cos_text_after_normalization']
df['diff_rho_after_normalization'] = df['rho_image_after_normalization'] - df['rho_text_after_normalization']
df.to_csv('data_3.csv', index=False)

# %% [markdown]
# ## Z score and Spearman's correlation

# %%
# cos before_normalization_p_value
cos_before_normalization_correlation, cos_before_normalization_p_value = spearmanr(df['cos_image_before_normalization'], df['cos_text_before_normalization'])

print(f"Spearman's correlation coefficient for before_normalization: {cos_before_normalization_correlation}")
print(f"before_normalization_p_value: {cos_before_normalization_p_value}")
# Out:
# Spearman's correlation coefficient for before_normalization: 0.17792196704516347
# before_normalization_p_value: 0.2069770027080461

# %%
# rho before_normalization_p_value
rho_before_normalization_correlation, rho_before_normalization_p_value = spearmanr(df['rho_image_before_normalization'], df['rho_text_before_normalization'])

print(f"Spearman's correlation coefficient for before_normalization: {rho_before_normalization_correlation}")
print(f"before_normalization_p_value: {rho_before_normalization_p_value}")
# Out:
# Spearman's correlation coefficient for before_normalization: 0.509177836591821
# before_normalization_p_value: 0.00011580047452896591

# %%
# cos after_normalization_p_value
cos_after_normalization_correlation, cos_after_normalization_p_value = spearmanr(df['cos_image_after_normalization'], df['cos_text_after_normalization'])

print(f"Spearman's correlation coefficient for after_normalization: {cos_after_normalization_correlation}")
print(f"after_normalization_p_value: {cos_after_normalization_p_value}")
# Out:
# Spearman's correlation coefficient for after_normalization: 0.2962520276615726
# after_normalization_p_value: 0.032965861850054165

# %%
# rho after_normalization_p_value
rho_after_normalization_correlation, rho_after_normalization_p_value = spearmanr(df['rho_image_after_normalization'], df['rho_text_after_normalization'])

print(f"Spearman's correlation coefficient for after_normalization: {rho_after_normalization_correlation}")
print(f"after_normalization_p_value: {rho_after_normalization_p_value}")
# Out:
# Spearman's correlation coefficient for after_normalization: 0.5353026551694698
# after_normalization_p_value: 4.334824398684485e-05

# %% [markdown]
# ## Plots

# %% [markdown]
# ### diff_cos_before_normalization

# %%
# Histogram
plt.figure(figsize=(5, 3))
sns.histplot(df['diff_cos_before_normalization'], bins=30, kde=True)
plt.title('Histogram of difference between cosine similarity of text and image embedding before normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplot
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['diff_cos_before_normalization'])
plt.title('Boxplot of diff_cos_before_normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.show()

# %%
# CDF
plt.figure(figsize=(5, 3))
sns.ecdfplot(df['diff_cos_before_normalization'])
plt.title('CDF of diff_cos_before_normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.ylabel('Cumulative Probability')
plt.show()

# %% [markdown]
# ### diff_rho_before_normalization

# %%
# Histogram
plt.figure(figsize=(5, 3))
sns.histplot(df['diff_rho_before_normalization'], bins=30, kde=True)
plt.title('Histogram of difference between spearman coefficient of text and image embedding before normalization')
plt.xlabel('Difference of spearman coefficient')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplot
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['diff_rho_before_normalization'])
plt.title('Boxplot of diff_rho_before_normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.show()

# %%
# CDF
plt.figure(figsize=(5, 3))
sns.ecdfplot(df['diff_rho_before_normalization'])
plt.title('CDF of diff_rho_before_normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.ylabel('Cumulative Probability')
plt.show()

# %% [markdown]
# ### diff_cos_after_normalization

# %%
# Histogram
plt.figure(figsize=(5, 3))
sns.histplot(df['diff_cos_after_normalization'], bins=30, kde=True)
plt.title('Histogram of difference between cosine similarity of text and image embedding after normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplot
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['diff_cos_after_normalization'])
plt.title('Boxplot of diff_cos_after_normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.show()

# %%
# CDF
plt.figure(figsize=(5, 3))
sns.ecdfplot(df['diff_cos_after_normalization'])
plt.title('CDF of diff_cos_after_normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.ylabel('Cumulative Probability')
plt.show()

# %% [markdown]
# ### diff_cos_after_normalization

# %%
# Histogram
plt.figure(figsize=(5, 3))
sns.histplot(df['diff_rho_after_normalization'], bins=30, kde=True)
plt.title('Histogram of difference between spearman coefficient of text and image embedding after normalization')
plt.xlabel('Difference of spearman coefficient')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplot
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['diff_rho_after_normalization'])
plt.title('Boxplot of diff_rho_after_normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.show()

# %%
# CDF
plt.figure(figsize=(5, 3))
sns.ecdfplot(df['diff_rho_after_normalization'])
plt.title('CDF of diff_rho_after_normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.ylabel('Cumulative Probability')
plt.show()

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import torch

def visualize_embeddings(embeddings1, embeddings2, word, title='t-SNE Visualization'):
    tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    combined_embeddings = np.concatenate((embeddings1, embeddings2))
    combined_labels = np.array([1] * len(embeddings1) + [2] * len(embeddings2))
    new_values = tsne_model.fit_transform(combined_embeddings)

    x = new_values[:, 0]
    y = new_values[:, 1]

    plt.figure(figsize=(10, 8)) 
    colors = ['blue' if label == 1 else 'red' for label in combined_labels]
    plt.scatter(x, y, c=colors, label=['Embeddings 1', 'Embeddings 2'])

    plt.text(np.mean(x[:len(embeddings1)]), np.mean(y[:len(embeddings1)]), 'Embeddings 1', fontsize=12, color='blue', ha='center')
    plt.text(np.mean(x[len(embeddings1):]), np.mean(y[len(embeddings1):]), 'Embeddings 2', fontsize=12, color='red', ha='center')

    plt.title(title)
    plt.legend()
    plt.show()


# Function to convert tensor string representation to NumPy array
def parse_tensor_string(tensor_string):
    # Remove 'tensor(' and ')' from the string
    tensor_string = tensor_string.replace('tensor(', '').replace(')', '')
    # Parse the string representation into a PyTorch tensor
    tensor = torch.tensor(eval(tensor_string))
    # Convert the PyTorch tensor to a NumPy array
    array = tensor.numpy()
    return array

# Example usage:
# Assuming you have a list of embeddings and corresponding words
embeddings = pd.read_csv("embeddings.csv")


# Convert each tensor string to a NumPy array
embeddings_offset = [parse_tensor_string(tensor_string) for tensor_string in embeddings['offset_vector_embedding_image']]
fourth_word_embedding = [parse_tensor_string(tensor_string) for tensor_string in embeddings['fourth_image_embedding']]
words = embeddings['pair1'].values


# Visualize embeddings
visualize_embeddings(embeddings_offset,fourth_word_embedding, words, 'T-SNE visualization for Image embedding')

# embeddings_offset = [parse_tensor_string(tensor_string) for tensor_string in embeddings['offset_vector_embedding_text']]

# visualize_embeddings(embeddings_offset, words, 'T-SNE visualization for Text embedding')

# %% [markdown]
# ## Clip image vs word2vec text:

# %%
df_wv = pd.read_csv('data_word2vec.csv')
df_wv.columns
# Out:
# Index(['pair1', 'pair2', 'cos_image_before_normalization',
#        'rho_image_before_normalization', 'cos_image_after_normalization',
#        'rho_image_after_normalization', 'cos_text_before_normalization',
#        'rho_text_before_normalization', 'cos_text_after_normalization',
#        'rho_text_after_normalization', 'w2v_cos_text_before_normalization',
#        'w2v_rho_text_before_normalization', 'w2v_cos_text_after_normalization',
#        'w2v_rho_text_after_normalization'],
#       dtype='object')

# %%
df_wv['w2v_diff_cos_before_normalization'] = df_wv['cos_image_before_normalization'] - df_wv['w2v_cos_text_before_normalization']
df_wv['w2v_diff_rho_before_normalization'] = df_wv['rho_image_before_normalization'] - df_wv['w2v_rho_text_before_normalization']
df_wv['w2v_diff_cos_after_normalization'] = df_wv['cos_image_after_normalization'] - df_wv['w2v_cos_text_after_normalization']
df_wv['w2v_diff_rho_after_normalization'] = df_wv['rho_image_after_normalization'] - df_wv['w2v_rho_text_after_normalization']
df_wv.to_csv('data_word2vec.csv', index=False)

# %%
# Histogram
plt.figure(figsize=(5, 3))
sns.histplot(df_wv['w2v_diff_cos_before_normalization'], bins=30, kde=True)
plt.title('Histogram of difference between cosine similarity of W2V text and CLIP image embedding before normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram
plt.figure(figsize=(5, 3))
sns.histplot(df_wv['w2v_diff_rho_before_normalization'], bins=30, kde=True)
plt.title('Histogram of difference between spearman coefficient of W2V text and CLIP image embedding before normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram
plt.figure(figsize=(5, 3))
sns.histplot(df_wv['w2v_diff_cos_after_normalization'], bins=30, kde=True)
plt.title('Histogram of difference between cosine similarity of W2V text and CLIP image embedding after normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram
plt.figure(figsize=(5, 3))
sns.histplot(df_wv['w2v_diff_rho_after_normalization'], bins=30, kde=True)
plt.title('Histogram of difference between spearman coefficient of W2V text and CLIP image embedding after normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Clip text vs word2vec text:

# %%
df_wv['w2v_text_diff_cos_before_normalization'] = df_wv['w2v_cos_text_before_normalization'] - df_wv['cos_text_before_normalization']
df_wv['w2v_text_diff_rho_before_normalization'] = df_wv['w2v_rho_text_before_normalization'] - df_wv['rho_text_before_normalization']
df_wv['w2v_text_diff_cos_after_normalization'] = df_wv['w2v_cos_text_after_normalization'] - df_wv['cos_text_after_normalization']
df_wv['w2v_text_diff_rho_after_normalization'] = df_wv['w2v_rho_text_after_normalization'] - df_wv['rho_text_after_normalization']
df_wv.to_csv('data_word2vec.csv', index=False)

# %%
# Histogram
plt.figure(figsize=(5, 3))
sns.histplot(df_wv['w2v_text_diff_cos_before_normalization'], bins=30, kde=True)
plt.title('Histogram of difference between cosine similarity of CLIP and W2V text embedding before normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram
plt.figure(figsize=(5, 3))
sns.histplot(df_wv['w2v_text_diff_rho_before_normalization'], bins=30, kde=True)
plt.title('Histogram of difference between Spearman similarity of CLIP and W2V text embedding before normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram
plt.figure(figsize=(5, 3))
sns.histplot(df_wv['w2v_text_diff_cos_after_normalization'], bins=30, kde=True)
plt.title('Histogram of difference between cosine similarity of CLIP and W2V text embedding after normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram
plt.figure(figsize=(5, 3))
sns.histplot(df_wv['w2v_text_diff_rho_after_normalization'], bins=30, kde=True)
plt.title('Histogram of difference between spearman similarity of CLIP and W2V text embedding after normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Clip image vs ResNet image

# %%
df_resnet = pd.read_csv('data_resnet.csv')
df_resnet.columns
# Out:
# Index(['pair1', 'pair2', 'cos_image_before_normalization',
#        'rho_image_before_normalization', 'cos_image_after_normalization',
#        'rho_image_after_normalization',
#        'resnet_cos_image_before_normalization',
#        'resnet_rho_image_before_normalization',
#        'resnet_cos_image_after_normalization',
#        'resnet_rho_image_after_normalization', 'cos_text_before_normalization',
#        'rho_text_before_normalization', 'cos_text_after_normalization',
#        'rho_text_after_normalization', 'w2v_cos_text_before_normalization',
#        'w2v_rho_text_before_normalization', 'w2v_cos_text_after_normalization',
#        'w2v_rho_text_after_normalization'],
#       dtype='object')

# %%
df_resnet['resnet_diff_cos_before_normalization'] = df_resnet['resnet_cos_image_before_normalization'] - df_resnet['cos_image_before_normalization']
df_resnet['resnet_diff_rho_before_normalization'] = df_resnet['resnet_rho_image_before_normalization'] - df_resnet['rho_image_before_normalization']
df_resnet['resnet_diff_cos_after_normalization'] = df_resnet['resnet_cos_image_after_normalization'] - df_resnet['cos_image_after_normalization']
df_resnet['resnet_diff_rho_after_normalization'] = df_resnet['resnet_rho_image_after_normalization'] - df_resnet['rho_image_after_normalization']
df_resnet.to_csv('data_resnet.csv', index=False)

# %%
# Histogram
plt.figure(figsize=(5, 3))
sns.histplot(df_resnet['resnet_diff_cos_before_normalization'], bins=30, kde=True)
plt.title('Histogram of difference between cosine similarity of ResNet and CLIP embedding before normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram
plt.figure(figsize=(5, 3))
sns.histplot(df_resnet['resnet_diff_rho_before_normalization'], bins=30, kde=True)
plt.title('Histogram of spearman coefficients of ResNet and CLIP embedding before normalization')
plt.xlabel('Difference of Spearman coeffeciant')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram
plt.figure(figsize=(5, 3))
sns.histplot(df_resnet['resnet_diff_cos_after_normalization'], bins=30, kde=True)
plt.title('Histogram of difference between cosine similarity of ResNet and CLIP embedding after normalization')
plt.xlabel('Difference of Cosine Similarities')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram
plt.figure(figsize=(5, 3))
sns.histplot(df_resnet['resnet_diff_rho_after_normalization'], bins=30, kde=True)
plt.title('Histogram of spearman coefficients of ResNet and CLIP embedding after normalization')
plt.xlabel('Difference of Spearman coeffeciant')
plt.ylabel('Frequency')
plt.show()

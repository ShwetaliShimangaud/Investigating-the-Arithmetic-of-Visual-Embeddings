# %%
# !pip install torch torchvision
# !pip install git+https://github.com/openai/CLIP.git
# !pip install scipy
# !pip install gensim
# Out:
# Requirement already satisfied: torch in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (2.1.2)
# Requirement already satisfied: torchvision in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (0.16.2)
# Requirement already satisfied: filelock in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from torch) (4.8.0)
# Requirement already satisfied: sympy in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from torch) (2023.10.0)
# Requirement already satisfied: numpy in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from torchvision) (1.26.0)
# Requirement already satisfied: requests in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from torchvision) (10.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from requests->torchvision) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from requests->torchvision) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /private/var/folders/cz/d_k7_tfn267938ylcg0bywxr0000gn/T/pip-req-build-b5p36idu
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /private/var/folders/cz/d_k7_tfn267938ylcg0bywxr0000gn/T/pip-req-build-b5p36idu
#   Resolved https://github.com/openai/CLIP.git to commit a1d071733d7111c9c014f024669f959182114e33
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ftfy in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from clip==1.0) (6.2.0)
# Requirement already satisfied: regex in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from clip==1.0) (2023.10.3)
# Requirement already satisfied: tqdm in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from clip==1.0) (4.66.1)
# Requirement already satisfied: torch in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from clip==1.0) (2.1.2)
# Requirement already satisfied: torchvision in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from clip==1.0) (0.16.2)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from torch->clip==1.0) (3.13.1)
# Requirement already satisfied: typing-extensions in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from torch->clip==1.0) (4.8.0)
# Requirement already satisfied: sympy in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from torch->clip==1.0) (1.12)
# Requirement already satisfied: networkx in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from torch->clip==1.0) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from torch->clip==1.0) (3.1.2)
# Requirement already satisfied: fsspec in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from torch->clip==1.0) (2023.10.0)
# Requirement already satisfied: numpy in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from torchvision->clip==1.0) (1.26.0)
# Requirement already satisfied: requests in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from torchvision->clip==1.0) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from torchvision->clip==1.0) (10.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from jinja2->torch->clip==1.0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from requests->torchvision->clip==1.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from requests->torchvision->clip==1.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from requests->torchvision->clip==1.0) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from requests->torchvision->clip==1.0) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from sympy->torch->clip==1.0) (1.3.0)
# Requirement already satisfied: scipy in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (1.11.3)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from scipy) (1.26.0)
# Requirement already satisfied: gensim in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from gensim) (1.26.0)
# Requirement already satisfied: scipy>=1.7.0 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from gensim) (1.11.3)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from gensim) (7.0.3)
# Requirement already satisfied: wrapt in /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages (from smart-open>=1.8.1->gensim) (1.14.1)

# %%
import torch
import torchvision.models as models
import torchvision.transforms as transforms
import clip

from PIL import Image
import os

import torch
import torch.nn.functional as F

import numpy as np
from gensim.models import Word2Vec
import gensim.downloader as api

device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
model, preprocess = clip.load("ViT-B/32", device=device)
w2v_model = api.load("word2vec-google-news-300")
resnet50_model = models.resnet50(pretrained=True)
resnet50_model.eval()
# Out:
# /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/rishabhthaney/.pyenv/versions/3.11.6/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
def get_image_embedding(image):
    preprocessed_image = preprocess(image).unsqueeze(0).to(device)
    with torch.no_grad():
        image_features = model.encode_image(preprocessed_image)
        return image_features

def get_text_embedding(text):
    with torch.no_grad():
        return model.encode_text(clip.tokenize([text]).to(device))

def get_text_embedding_word2vec(text):
    words = text.split()

    embeddings = []

    for word in words:
        if word in w2v_model.key_to_index:
            word_embedding = w2v_model.get_vector(word)
            embeddings.append(word_embedding)

    if len(embeddings) == 0:
        return None

    embeddings = np.array(embeddings)
    text_embedding = np.mean(embeddings, axis=0)

    # Convert the NumPy array to a torch tensor
    text_embedding_tensor = torch.tensor(text_embedding)

    return text_embedding_tensor

def get_images_from_folder(folder_path):
    images = []

    for filename in os.listdir(folder_path):
        # Check if the file is an image file
        if filename.endswith(".jpg") or filename.endswith(".png") or filename.endswith(
#           -1.7607e-01, -1.3090e-01, -2.7871e-01,  1.0900e-01, -5.4096e-02,
#           -4.4804e-01,  4.4635e-01, -1.7581e-01, -7.5667e-01, -9.4552e-02,
#            7.0698e-01,  7.3145e-01, -4.4603e-01,  1.0066e-01, -1.1148e+00,
#            1.9268e-01, -8.9748e-01, -1.2462e-01, -4.0525e-01, -1.5148e-01,
#            3.1912e-01,  5.3519e-01, -4.8887e-02, -3.7567e-01, -1.1165e-01,
#            2.3018e-01,  9.3302e-02, -1.2776e-01, -5.0452e-01,  3.2350e-01,
#            2.2673e-01,  1.7279e-01, -4.9650e-01, -1.2369e-01, -4.2899e-04,
#            1.0024e-01, -5.0811e-01,  5.9263e-01, -3.2710e-01,  1.9690e-01,
#           -1.0912e-01, -1.5590e-01,  1.1920e-01,  2.1859e-02, -3.5658e-02,
#            2.5004e-01, -6.0264e-02,  2.8328e-01, -3.0021e-01,  2.8026e-01,
#           -3.2524e-01, -2.2110e-01, -2.3104e-01,  3.9949e-01,  4.6689e-02,
#            3.2989e-02, -1.0212e-01, -8.5693e-02, -4.5730e-02,  1.4910e-01,
#           -1.1229e-01, -6.4585e-01, -2.7042e-01, -2.5651e-01,  4.3930e-01,
#           -2.7347e-01, -3.8560e-02]])]

# %%
# Resnet image embedding 

preprocess_image = transforms.Compose([
    transforms.Resize(256),                   # Resize image to 256x256
    transforms.CenterCrop(224),               # Center crop image to 224x224
    transforms.ToTensor(),                    # Convert PIL image to tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize image
])

def get_resnet_image_embedding(image_path):
    # Open and preprocess the image
    image = Image.open(image_path).convert("RGB")
    preprocessed_image = preprocess_image(image).unsqueeze(0)
    
    # Forward pass through the model to get image features
    with torch.no_grad():
        image_features = resnet50_model(preprocessed_image)

    return image_features

# def get_resnet_images_from_folder(folder_path):
#     images = []

#     for filename in os.listdir(folder_path):
#         # Check if the file is an image file
#         if filename.endswith(".jpg") or filename.endswith(".png") or filename.endswith(".jpeg"):
#             # Open the image using PIL
#             image_path = os.path.join(folder_path, filename)
#             image = Image.open(image_path)
#             # Append the image to the list
#             images.append(get_resnet_image_embedding(image))

#     return images

def get_resnet_images_from_folder(folder_path):
    images = []

    for filename in os.listdir(folder_path):
        # Check if the file is an image file
        if filename.endswith(".jpg") or filename.endswith(".png") or filename.endswith(".jpeg"):
            # Open the image using PIL
            image_path = os.path.join(folder_path, filename)
            # Append the image path to the list
            images.append(get_resnet_image_embedding(image_path))

    return images

# %%
from scipy.stats import spearmanr

def find_image_embedding_arithmetics(pair1,pair2):
    first_pair = pair1.split(':')
    second_pair = pair2.split(':')

    first_image_embeddings = get_images_from_folder(os.path.join("new_images" ,first_pair[0]))
    second_image_embeddings = get_images_from_folder(os.path.join("new_images" ,first_pair[1]))
    third_image_embeddings = get_images_from_folder(os.path.join("new_images" ,second_pair[0]))
    fourth_image_embeddings = get_images_from_folder(os.path.join("new_images" ,second_pair[1]))


    first_image_embeddings = torch.squeeze(torch.stack(first_image_embeddings, dim=0), dim=1)
    second_image_embeddings = torch.squeeze(torch.stack(second_image_embeddings, dim=0), dim=1)
    third_image_embeddings = torch.squeeze(torch.stack(third_image_embeddings, dim=0), dim=1)
    fourth_image_embeddings = torch.squeeze(torch.stack(fourth_image_embeddings, dim=0), dim=1)

    # Average of embeddings
    first_image_embeddings = torch.mean(first_image_embeddings, dim=0)
    second_image_embeddings = torch.mean(second_image_embeddings, dim=0)
    third_image_embeddings = torch.mean(third_image_embeddings, dim=0)
    fourth_image_embeddings = torch.mean(fourth_image_embeddings, dim=0)


    offset_vector_embedding = second_image_embeddings - first_image_embeddings + third_image_embeddings

    cos_sim = F.cosine_similarity(offset_vector_embedding, fourth_image_embeddings, dim=0)

    cos_image_before_normalization = torch.rad2deg(torch.acos(cos_sim))

    print("Angle for Image embedding before normalizing: Averaging ", cos_image_before_normalization)

    rho_image_before_normalization, p_value = spearmanr(offset_vector_embedding.cpu().numpy(), fourth_image_embeddings.cpu().numpy())
    print("Spearman's correlation coefficient for Image embedding before normalizing:", rho_image_before_normalization)


    first_image_embeddings = F.normalize(first_image_embeddings , p=2,dim=0)
    second_image_embeddings = F.normalize(second_image_embeddings , p=2,dim=0)
    third_image_embeddings = F.normalize(third_image_embeddings, p=2,dim=0)
    fourth_image_embeddings = F.normalize(fourth_image_embeddings , p=2,dim=0)

    offset_vector_embedding = second_image_embeddings - first_image_embeddings + third_image_embeddings

    cos_sim = F.cosine_similarity(offset_vector_embedding, fourth_image_embeddings, dim=0)

    cos_image_after_normalization = torch.rad2deg(torch.acos(cos_sim))

    print("Angle for Image embedding after normalizing: Averaging ", cos_image_after_normalization)

    rho_image_after_normalization, p_value = spearmanr(offset_vector_embedding.cpu().numpy(), fourth_image_embeddings.cpu().numpy())
    print("Spearman's correlation coefficient for Image embedding after normalizing:", rho_image_after_normalization)

    return cos_image_before_normalization, rho_image_before_normalization,cos_image_after_normalization, rho_image_after_normalization, offset_vector_embedding, fourth_image_embeddings


def find_text_embedding_arithmetics(pair1,pair2): 
    first_pair = pair1.split(':')
    second_pair = pair2.split(':')

    first = get_text_embedding(first_pair[0]).squeeze(0)
    second = get_text_embedding(first_pair[1]).squeeze(0)
    third = get_text_embedding(second_pair[0]).squeeze(0)
    fourth = get_text_embedding(second_pair[1]).squeeze(0)

    offset_vector_embedding = second - first + third

    # King - Queen + Man = Woman

    cos_sim_init = F.cosine_similarity(offset_vector_embedding, fourth, dim=0)

    cos_text_before_normalization = torch.rad2deg(torch.acos(cos_sim_init))

    print("Angle for text embedding before normalizing: Averaging ", cos_text_before_normalization)
    rho_text_before_normalization , p_value = spearmanr(offset_vector_embedding.cpu().numpy(), fourth.cpu().numpy())
    print("Spearman's correlation coefficient for text embedding before normalizing:", rho_text_before_normalization)

    first = F.normalize(first , p=2,dim=0)
    second = F.normalize(second , p=2,dim=0)
    third = F.normalize(third , p=2,dim=0)
    fourth = F.normalize(fourth, p=2,dim=0)

    offset_vector_embedding = second - first + third

    cos_sim = F.cosine_similarity(offset_vector_embedding, fourth, dim=0)

    cos_text_after_normalization = torch.rad2deg(torch.acos(cos_sim))

    print("Angle for text embedding after normalizing: Averaging ", cos_text_after_normalization)
    rho_text_after_normalization, p_value = spearmanr(offset_vector_embedding.cpu().numpy(), fourth.cpu().numpy())
    print("Spearman's correlation coefficient for text embedding after normalizing:", rho_text_after_normalization)

    return cos_sim_init, cos_text_before_normalization, rho_text_before_normalization, cos_text_after_normalization, rho_text_after_normalization, offset_vector_embedding, fourth

def find_w2v_text_embedding_arithmetics(pair1,pair2): 
    first_pair = pair1.split(':')
    second_pair = pair2.split(':')

    w2v_first = get_text_embedding_word2vec(first_pair[0])
    w2v_second = get_text_embedding_word2vec(first_pair[1])
    w2v_third = get_text_embedding_word2vec(second_pair[0])
    w2v_fourth = get_text_embedding_word2vec(second_pair[1])

    w2v_offset_vector_embedding = w2v_second - w2v_first + w2v_third

    # King - Queen + Man = Woman

    w2v_cos_sim_init = F.cosine_similarity(w2v_offset_vector_embedding, w2v_fourth, dim=0)

    w2v_cos_text_before_normalization = torch.rad2deg(torch.acos(w2v_cos_sim_init))

    print("Word2Vec Angle for text embedding before normalizing: Averaging ", w2v_cos_text_before_normalization)
    w2v_rho_text_before_normalization , w2v_p_value = spearmanr(w2v_offset_vector_embedding.cpu().numpy(), w2v_fourth.cpu().numpy())
    print("Word2Vec Spearman's correlation coefficient for text embedding before normalizing:", w2v_rho_text_before_normalization)

    w2v_first = F.normalize(w2v_first , p=2,dim=0)
    w2v_second = F.normalize(w2v_second , p=2,dim=0)
    w2v_third = F.normalize(w2v_third , p=2,dim=0)
    w2v_fourth = F.normalize(w2v_fourth, p=2,dim=0)

    w2v_offset_vector_embedding = w2v_second - w2v_first + w2v_third

    w2v_cos_sim = F.cosine_similarity(w2v_offset_vector_embedding, w2v_fourth, dim=0)

    w2v_cos_text_after_normalization = torch.rad2deg(torch.acos(w2v_cos_sim))

    print("Word2Vec Angle for text embedding after normalizing: Averaging ", w2v_cos_text_after_normalization)
    w2v_rho_text_after_normalization, w2v_p_value = spearmanr(w2v_offset_vector_embedding.cpu().numpy(), w2v_fourth.cpu().numpy())
    print("Word2Vec Spearman's correlation coefficient for text embedding after normalizing:", w2v_rho_text_after_normalization)

    return w2v_cos_sim_init, w2v_cos_text_before_normalization, w2v_rho_text_before_normalization, w2v_cos_text_after_normalization, w2v_rho_text_after_normalization, w2v_offset_vector_embedding, w2v_fourth

def find_resnet_image_embedding_arithmetics(pair1,pair2):
    first_pair = pair1.split(':')
    second_pair = pair2.split(':')

    first_image_embeddings = get_resnet_images_from_folder(os.path.join("new_images" ,first_pair[0]))
    second_image_embeddings = get_resnet_images_from_folder(os.path.join("new_images" ,first_pair[1]))
    third_image_embeddings = get_resnet_images_from_folder(os.path.join("new_images" ,second_pair[0]))
    resnet_fourth_image_embeddings = get_resnet_images_from_folder(os.path.join("new_images" ,second_pair[1]))


    first_image_embeddings = torch.squeeze(torch.stack(first_image_embeddings, dim=0), dim=1)
    second_image_embeddings = torch.squeeze(torch.stack(second_image_embeddings, dim=0), dim=1)
    third_image_embeddings = torch.squeeze(torch.stack(third_image_embeddings, dim=0), dim=1)
    resnet_fourth_image_embeddings = torch.squeeze(torch.stack(resnet_fourth_image_embeddings, dim=0), dim=1)

    # Average of embeddings
    first_image_embeddings = torch.mean(first_image_embeddings, dim=0)
    second_image_embeddings = torch.mean(second_image_embeddings, dim=0)
    third_image_embeddings = torch.mean(third_image_embeddings, dim=0)
    resnet_fourth_image_embeddings = torch.mean(resnet_fourth_image_embeddings, dim=0)


    resnet_offset_vector_embedding = second_image_embeddings - first_image_embeddings + third_image_embeddings

    cos_sim = F.cosine_similarity(resnet_offset_vector_embedding, resnet_fourth_image_embeddings, dim=0)

    resnet_cos_image_before_normalization = torch.rad2deg(torch.acos(cos_sim))

    print("Angle for Image embedding before normalizing: Averaging ", resnet_cos_image_before_normalization)

    resnet_rho_image_before_normalization, p_value = spearmanr(resnet_offset_vector_embedding.cpu().numpy(), resnet_fourth_image_embeddings.cpu().numpy())
    print("Spearman's correlation coefficient for Image embedding before normalizing:", resnet_rho_image_before_normalization)


    first_image_embeddings = F.normalize(first_image_embeddings , p=2,dim=0)
    second_image_embeddings = F.normalize(second_image_embeddings , p=2,dim=0)
    third_image_embeddings = F.normalize(third_image_embeddings, p=2,dim=0)
    resnet_fourth_image_embeddings = F.normalize(resnet_fourth_image_embeddings , p=2,dim=0)

    resnet_offset_vector_embedding = second_image_embeddings - first_image_embeddings + third_image_embeddings

    cos_sim = F.cosine_similarity(resnet_offset_vector_embedding, resnet_fourth_image_embeddings, dim=0)

    resnet_cos_image_after_normalization = torch.rad2deg(torch.acos(cos_sim))

    print("Angle for Image embedding after normalizing: Averaging ", resnet_cos_image_after_normalization)

    resnet_rho_image_after_normalization, p_value = spearmanr(resnet_offset_vector_embedding.cpu().numpy(), resnet_fourth_image_embeddings.cpu().numpy())
    print("Spearman's correlation coefficient for Image embedding after normalizing:", resnet_rho_image_after_normalization)

    return resnet_cos_image_before_normalization, resnet_rho_image_before_normalization, resnet_cos_image_after_normalization, resnet_rho_image_after_normalization, resnet_offset_vector_embedding, resnet_fourth_image_embeddings

# %%
# pair1 = "hour:seconds"
# pair2 = "feet:inches"
# find_resnet_image_embedding_arithmetics(pair1,pair2)

# %%
import os
import glob
import pandas as pd


def process_file(pair):

    pairs = pair.split("::")
    pair1 = pairs[0]
    pair2 = pairs[1]

    # image embedding results
    cos_image_before_normalization, rho_image_before_normalization,cos_image_after_normalization, rho_image_after_normalization, offset_vector_embedding_image, fourth_image_embedding = find_image_embedding_arithmetics(pair1,pair2)
    resnet_cos_image_before_normalization, resnet_rho_image_before_normalization, resnet_cos_image_after_normalization, resnet_rho_image_after_normalization, resnet_offset_vector_embedding_image, resnet_fourth_image_embedding = find_resnet_image_embedding_arithmetics(pair1,pair2)

    # word embedding results
    cos_sim_init, cos_text_before_normalization, rho_text_before_normalization, cos_text_after_normalization, rho_text_after_normalization, offset_vector_embedding_text, fourth_text_embedding = find_text_embedding_arithmetics(pair1,pair2)
    w2v_cos_sim_init, w2v_cos_text_before_normalization, w2v_rho_text_before_normalization, w2v_cos_text_after_normalization, w2v_rho_text_after_normalization, w2v_offset_vector_embedding_text, w2v_fourth_text_embedding = find_w2v_text_embedding_arithmetics(pair1,pair2)

    new_data = {
        'pair1':pair1,
        'pair2':pair2,

        'cos_image_before_normalization':cos_image_before_normalization.item(),
        'rho_image_before_normalization':rho_image_before_normalization.item(),
        'cos_image_after_normalization':cos_image_after_normalization.item(),
        'rho_image_after_normalization':rho_image_after_normalization.item(),

        'resnet_cos_image_before_normalization':resnet_cos_image_before_normalization.item(),
        'resnet_rho_image_before_normalization':resnet_rho_image_before_normalization.item(),
        'resnet_cos_image_after_normalization':resnet_cos_image_after_normalization.item(),
        'resnet_rho_image_after_normalization':resnet_rho_image_after_normalization.item(),

        'cos_text_before_normalization':cos_text_before_normalization.item(),
        'rho_text_before_normalization':rho_text_before_normalization.item(),
        'cos_text_after_normalization':cos_text_after_normalization.item(),
        'rho_text_after_normalization':rho_text_after_normalization.item(),

        'w2v_cos_text_before_normalization':w2v_cos_text_before_normalization.item(),
        'w2v_rho_text_before_normalization':w2v_rho_text_before_normalization.item(),
        'w2v_cos_text_after_normalization':w2v_cos_text_after_normalization.item(),
        'w2v_rho_text_after_normalization':w2v_rho_text_after_normalization.item(),

        'cos_sim_init_CLIP': cos_sim_init.item(),
        'cos_sim_init_W2V': w2v_cos_sim_init.item()
        
    }

    embedding_data = {
        'pair1':pair1,
        'pair2':pair2,

        'offset_vector_embedding_image' : offset_vector_embedding_image,
        'fourth_image_embedding' : fourth_image_embedding,

        'resnet_offset_vector_embedding_image' : resnet_offset_vector_embedding_image,
        'resnet_fourth_image_embedding' : resnet_fourth_image_embedding,

        'offset_vector_embedding_text' : offset_vector_embedding_text,
        'fourth_text_embedding':fourth_text_embedding,
        
        'w2v_offset_vector_embedding_text' : w2v_offset_vector_embedding_text,
        'w2v_fourth_text_embedding':w2v_fourth_text_embedding
    }

    return new_data, embedding_data

# %%
results = []
embedding_results = []

# Process Training and Testing folders
# for sub_folder in ['Training', 'Testing']:
#     sub_folder_path = os.path.join(data_folder, sub_folder)
#     process_folder(sub_folder_path,results,embedding_results)

lines = []

with open('new_pairs.txt', 'r') as file:
    for line in file:
        # Remove newline character at the end of each line and append to the list
        lines.append(line.strip())
        
for pair in lines:
    print("---- Pair ----" ,pair)
    similarity_data, embedding_data = process_file(pair)
    results.append(similarity_data)
    embedding_results.append(embedding_data)

df = pd.DataFrame(results)

df.to_csv('data_w2v_cos_sim.csv', index=False) # TODO: new file

df_embedding = pd.DataFrame(embedding_results)

df_embedding.to_csv('embeddings_w2v_cos_sim.csv', index=False) # TODO: new file
# Out:
# ---- Pair ---- hour:seconds::feet:inches
# Angle for Image embedding before normalizing: Averaging  tensor(44.0971)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.40121726262002033
# Angle for Image embedding after normalizing: Averaging  tensor(35.3036)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.4918100223446745
# Angle for Image embedding before normalizing: Averaging  tensor(56.2933)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5911476631476632
# Angle for Image embedding after normalizing: Averaging  tensor(50.7823)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.6504458784458784
# Angle for text embedding before normalizing: Averaging  tensor(43.1168)
# Spearman's correlation coefficient for text embedding before normalizing: 0.2857623868461107
# Angle for text embedding after normalizing: Averaging  tensor(38.9310)
# Spearman's correlation coefficient for text embedding after normalizing: 0.30123405331250497
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(58.0464)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.5296546773910836
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(59.3113)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.5160762070295298
# ---- Pair ---- kid:child::raise:elevate
# Angle for Image embedding before normalizing: Averaging  tensor(18.0013)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.8003215623247616
# Angle for Image embedding after normalizing: Averaging  tensor(18.8804)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.7876761502786646
# Angle for Image embedding before normalizing: Averaging  tensor(21.0733)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.9390280710280713
# Angle for Image embedding after normalizing: Averaging  tensor(22.3906)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.9316964476964479
# Angle for text embedding before normalizing: Averaging  tensor(32.9414)
# Spearman's correlation coefficient for text embedding before normalizing: 0.34155648110001025
# Angle for text embedding after normalizing: Averaging  tensor(32.3152)
# Spearman's correlation coefficient for text embedding after normalizing: 0.34962102030189635
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(76.4940)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.21207775014210742
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(76.1316)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.22175772153226447
# ---- Pair ---- library:books::bird:feathers
# Angle for Image embedding before normalizing: Averaging  tensor(37.3273)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5022428717341298
# Angle for Image embedding after normalizing: Averaging  tensor(38.5901)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.49989235360089723
# Angle for Image embedding before normalizing: Averaging  tensor(59.4314)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5288396528396528
# Angle for Image embedding after normalizing: Averaging  tensor(57.0218)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.5650814170814171
# Angle for text embedding before normalizing: Averaging  tensor(34.4877)
# Spearman's correlation coefficient for text embedding before normalizing: 0.3644085420457536
# Angle for text embedding after normalizing: Averaging  tensor(36.1023)
# Spearman's correlation coefficient for text embedding after normalizing: 0.34332772928325384
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(70.6589)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.31343925218450097
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(71.5692)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.304083686657034
# ---- Pair ---- weapon:spear::bird:robin
# Angle for Image embedding before normalizing: Averaging  tensor(34.6815)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.6095167105835364
# Angle for Image embedding after normalizing: Averaging  tensor(35.1576)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.6110264423902222
# Angle for Image embedding before normalizing: Averaging  tensor(52.4692)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5488435648435649
# Angle for Image embedding after normalizing: Averaging  tensor(47.5039)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.6108256428256429
# Angle for text embedding before normalizing: Averaging  tensor(42.0221)
# Spearman's correlation coefficient for text embedding before normalizing: 0.3118230972694293
# Angle for text embedding after normalizing: Averaging  tensor(39.8505)
# Spearman's correlation coefficient for text embedding after normalizing: 0.3221830797026814
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(60.7675)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.47571659527998267
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(60.1953)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.485808331647856
# ---- Pair ---- wash:clean::teach:educated
# Angle for Image embedding before normalizing: Averaging  tensor(37.9315)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.43768730831073127
# Angle for Image embedding after normalizing: Averaging  tensor(34.6099)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.4748374753951088
# Angle for Image embedding before normalizing: Averaging  tensor(47.1682)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.7313209193209194
# Angle for Image embedding after normalizing: Averaging  tensor(45.0803)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.7591677871677872
# Angle for text embedding before normalizing: Averaging  tensor(25.7882)
# Spearman's correlation coefficient for text embedding before normalizing: 0.43186608787951614
# Angle for text embedding after normalizing: Averaging  tensor(27.7687)
# Spearman's correlation coefficient for text embedding after normalizing: 0.41452768622469416
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(71.6205)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.29857625167913315
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(71.4961)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.3024685089110415
# ---- Pair ---- spinner:yarn::weaver:cloth
# Angle for Image embedding before normalizing: Averaging  tensor(40.9610)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5047148049919318
# Angle for Image embedding after normalizing: Averaging  tensor(43.2885)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.4809088574747371
# Angle for Image embedding before normalizing: Averaging  tensor(61.3733)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.4355555795555796
# Angle for Image embedding after normalizing: Averaging  tensor(66.5530)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.3624626424626425
# Angle for text embedding before normalizing: Averaging  tensor(43.0755)
# Spearman's correlation coefficient for text embedding before normalizing: 0.3351105718062279
# Angle for text embedding after normalizing: Averaging  tensor(42.8075)
# Spearman's correlation coefficient for text embedding after normalizing: 0.3393669855288907
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(67.7495)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.36162415950222493
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(67.4799)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.36756270623541226
# ---- Pair ---- hunger:starvation::sadness:depression
# Angle for Image embedding before normalizing: Averaging  tensor(36.8477)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.508150370217782
# Angle for Image embedding after normalizing: Averaging  tensor(35.5117)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.522503283036358
# Angle for Image embedding before normalizing: Averaging  tensor(30.7915)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.8656565416565417
# Angle for Image embedding after normalizing: Averaging  tensor(32.2754)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.8516387036387038
# Angle for text embedding before normalizing: Averaging  tensor(27.5772)
# Spearman's correlation coefficient for text embedding before normalizing: 0.4655551192478914
# Angle for text embedding after normalizing: Averaging  tensor(28.3813)
# Spearman's correlation coefficient for text embedding after normalizing: 0.4548088078357995
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(76.1700)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.2439781422787061
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(77.2480)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.22475182078485048
# ---- Pair ---- crown:royalty::smoke:fire
# Angle for Image embedding before normalizing: Averaging  tensor(33.2482)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5415554439752349
# Angle for Image embedding after normalizing: Averaging  tensor(32.9437)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.5394558921561896
# Angle for Image embedding before normalizing: Averaging  tensor(58.2697)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5079533799533801
# Angle for Image embedding after normalizing: Averaging  tensor(56.6757)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.5358164958164958
# Angle for text embedding before normalizing: Averaging  tensor(30.9766)
# Spearman's correlation coefficient for text embedding before normalizing: 0.3216292014282281
# Angle for text embedding after normalizing: Averaging  tensor(33.4874)
# Spearman's correlation coefficient for text embedding after normalizing: 0.30276694161202095
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(70.1422)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.33233275843845844
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(70.7311)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.32189401632215414
# ---- Pair ---- fail:succeed::attract:repel
# Angle for Image embedding before normalizing: Averaging  tensor(47.5632)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.237009922780696
# Angle for Image embedding after normalizing: Averaging  tensor(50.9928)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.21674387881804968
# Angle for Image embedding before normalizing: Averaging  tensor(39.7044)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.7514800274800275
# Angle for Image embedding after normalizing: Averaging  tensor(46.0409)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.6743585903585904
# Angle for text embedding before normalizing: Averaging  tensor(45.4560)
# Spearman's correlation coefficient for text embedding before normalizing: 0.2849663935809844
# Angle for text embedding after normalizing: Averaging  tensor(41.5843)
# Spearman's correlation coefficient for text embedding after normalizing: 0.29538502720843207
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(74.9136)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.22185191975545068
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(75.8383)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.20781034371851032
# ---- Pair ---- tired:exhaustion::morose:sadness
# Angle for Image embedding before normalizing: Averaging  tensor(32.0822)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.4392584629381674
# Angle for Image embedding after normalizing: Averaging  tensor(28.5102)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.49204972333802544
# Angle for Image embedding before normalizing: Averaging  tensor(37.4609)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.7863368703368705
# Angle for Image embedding after normalizing: Averaging  tensor(31.9004)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.8462816582816584
# Angle for text embedding before normalizing: Averaging  tensor(30.9876)
# Spearman's correlation coefficient for text embedding before normalizing: 0.38595409399640657
# Angle for text embedding after normalizing: Averaging  tensor(30.4687)
# Spearman's correlation coefficient for text embedding after normalizing: 0.38913484839381557
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(70.5512)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.28846985698416283
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(70.9066)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.2856787295743127
# ---- Pair ---- fire:cold::rainbow:monochromatic
# Angle for Image embedding before normalizing: Averaging  tensor(45.4280)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.29608606991222347
# Angle for Image embedding after normalizing: Averaging  tensor(43.6451)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.30377804886073634
# Angle for Image embedding before normalizing: Averaging  tensor(69.6471)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.3558992118992119
# Angle for Image embedding after normalizing: Averaging  tensor(60.1563)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.49292311292311297
# Angle for text embedding before normalizing: Averaging  tensor(42.3393)
# Spearman's correlation coefficient for text embedding before normalizing: 0.22619503596319562
# Angle for text embedding after normalizing: Averaging  tensor(39.9064)
# Spearman's correlation coefficient for text embedding after normalizing: 0.22922263564161546
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(73.3735)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.29943552417867664
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(73.5501)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.29641486605819967
# ---- Pair ---- laugh:happiness::nod:agreement
# Angle for Image embedding before normalizing: Averaging  tensor(56.8881)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.1596283445485861
# Angle for Image embedding after normalizing: Averaging  tensor(52.4778)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.17736344643000196
# Angle for Image embedding before normalizing: Averaging  tensor(56.8525)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5435485235485237
# Angle for Image embedding after normalizing: Averaging  tensor(56.4701)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.5515615555615556
# Angle for text embedding before normalizing: Averaging  tensor(33.3014)
# Spearman's correlation coefficient for text embedding before normalizing: 0.10551913101818473
# Angle for text embedding after normalizing: Averaging  tensor(35.3329)
# Spearman's correlation coefficient for text embedding after normalizing: 0.08460175481511999
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(85.7948)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.020921978171776257
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(85.5916)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.026145713898879628
# ---- Pair ---- retiree:job::widow:husband
# Angle for Image embedding before normalizing: Averaging  tensor(55.3391)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.13867368549799156
# Angle for Image embedding after normalizing: Averaging  tensor(58.9123)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.09262364673098271
# Angle for Image embedding before normalizing: Averaging  tensor(42.9990)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.7416884856884857
# Angle for Image embedding after normalizing: Averaging  tensor(50.8470)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.6261705501705502
# Angle for text embedding before normalizing: Averaging  tensor(38.4947)
# Spearman's correlation coefficient for text embedding before normalizing: 0.2581094216706149
# Angle for text embedding after normalizing: Averaging  tensor(38.9354)
# Spearman's correlation coefficient for text embedding after normalizing: 0.2612030039425046
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(73.5806)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.2958626838449977
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(70.4567)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.34540479110592176
# ---- Pair ---- unstable:fall::fragile:break
# Angle for Image embedding before normalizing: Averaging  tensor(39.7317)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.4459602559480894
# Angle for Image embedding after normalizing: Averaging  tensor(40.6878)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.45426100925830565
# Angle for Image embedding before normalizing: Averaging  tensor(58.3058)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5151403071403072
# Angle for Image embedding after normalizing: Averaging  tensor(59.0068)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.5036454116454118
# Angle for text embedding before normalizing: Averaging  tensor(49.0765)
# Spearman's correlation coefficient for text embedding before normalizing: 0.23152729300078675
# Angle for text embedding after normalizing: Averaging  tensor(42.9004)
# Spearman's correlation coefficient for text embedding after normalizing: 0.25432230690882457
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(75.0114)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.2500906958663112
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(73.4047)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.26950731605437117
# ---- Pair ---- harvesting:farming::stitching:sewing
# Angle for Image embedding before normalizing: Averaging  tensor(26.2742)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.6095639176422792
# Angle for Image embedding after normalizing: Averaging  tensor(26.1135)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.6111644872741213
# Angle for Image embedding before normalizing: Averaging  tensor(49.8494)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.6595680595680596
# Angle for Image embedding after normalizing: Averaging  tensor(50.5938)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.650988554988555
# Angle for text embedding before normalizing: Averaging  tensor(31.7974)
# Spearman's correlation coefficient for text embedding before normalizing: 0.5959318959499205
# Angle for text embedding after normalizing: Averaging  tensor(31.0193)
# Spearman's correlation coefficient for text embedding after normalizing: 0.6061268324921893
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(60.1497)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.498237693050462
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(60.6952)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.49176936923003506
# ---- Pair ---- botany:plants::mathematics:numbers
# Angle for Image embedding before normalizing: Averaging  tensor(29.9644)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5500252665053044
# Angle for Image embedding after normalizing: Averaging  tensor(32.8803)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.5239345152264222
# Angle for Image embedding before normalizing: Averaging  tensor(44.4535)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.7145995385995386
# Angle for Image embedding after normalizing: Averaging  tensor(45.5234)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.7013758853758855
# Angle for text embedding before normalizing: Averaging  tensor(28.8419)
# Spearman's correlation coefficient for text embedding before normalizing: 0.4590604829711264
# Angle for text embedding after normalizing: Averaging  tensor(30.8750)
# Spearman's correlation coefficient for text embedding after normalizing: 0.43472309841384277
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(80.1083)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.14599281277290532
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(80.0651)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.14374328323298546
# ---- Pair ---- millionaire:wealth::coward:fear
# Angle for Image embedding before normalizing: Averaging  tensor(27.7527)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5568280003662124
# Angle for Image embedding after normalizing: Averaging  tensor(27.3775)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.5650646486364312
# Angle for Image embedding before normalizing: Averaging  tensor(39.4393)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.79001473001473
# Angle for Image embedding after normalizing: Averaging  tensor(38.9329)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.7951065631065631
# Angle for text embedding before normalizing: Averaging  tensor(29.8933)
# Spearman's correlation coefficient for text embedding before normalizing: 0.2898566157116536
# Angle for text embedding after normalizing: Averaging  tensor(30.7473)
# Spearman's correlation coefficient for text embedding after normalizing: 0.28199377939712295
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(75.8115)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.24077290177230323
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(76.1949)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.2325278909981455
# ---- Pair ---- library:books::school:student
# Angle for Image embedding before normalizing: Averaging  tensor(37.2945)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.37188996678339686
# Angle for Image embedding after normalizing: Averaging  tensor(39.1968)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.34092615957702477
# Angle for Image embedding before normalizing: Averaging  tensor(54.4089)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5878518718518718
# Angle for Image embedding after normalizing: Averaging  tensor(52.3170)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.6208322008322008
# Angle for text embedding before normalizing: Averaging  tensor(27.2778)
# Spearman's correlation coefficient for text embedding before normalizing: 0.3256724681280828
# Angle for text embedding after normalizing: Averaging  tensor(30.2212)
# Spearman's correlation coefficient for text embedding after normalizing: 0.2562405407067898
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(72.0829)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.33371293191581547
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(69.4205)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.3691839993264858
# ---- Pair ---- consume:edible::eat:edible
# Angle for Image embedding before normalizing: Averaging  tensor(15.7061)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.8946045192890903
# Angle for Image embedding after normalizing: Averaging  tensor(14.7540)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.9035296932399492
# Angle for Image embedding before normalizing: Averaging  tensor(19.3127)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.9242856602856603
# Angle for Image embedding after normalizing: Averaging  tensor(16.5763)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.9441099081099081
# Angle for text embedding before normalizing: Averaging  tensor(24.2848)
# Spearman's correlation coefficient for text embedding before normalizing: 0.7519142998764032
# Angle for text embedding after normalizing: Averaging  tensor(23.9595)
# Spearman's correlation coefficient for text embedding after normalizing: 0.7608373280518649
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(37.8889)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.745517706067039
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(38.6537)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.7361045616337845
# ---- Pair ---- hot:cold::big:small
# Angle for Image embedding before normalizing: Averaging  tensor(39.8357)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.44074307129124185
# Angle for Image embedding after normalizing: Averaging  tensor(41.2926)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.4370028953662695
# Angle for Image embedding before normalizing: Averaging  tensor(82.1333)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.12963366963366965
# Angle for Image embedding after normalizing: Averaging  tensor(72.9148)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.27816949416949416
# Angle for text embedding before normalizing: Averaging  tensor(29.6272)
# Spearman's correlation coefficient for text embedding before normalizing: 0.41311800119591213
# Angle for text embedding after normalizing: Averaging  tensor(28.7019)
# Spearman's correlation coefficient for text embedding after normalizing: 0.4219116569963722
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(69.7362)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.3355386295934767
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(67.3856)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.3674691084250227
# ---- Pair ---- omelette:eggs::ocean:water
# Angle for Image embedding before normalizing: Averaging  tensor(37.1473)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.44619360902255634
# Angle for Image embedding after normalizing: Averaging  tensor(38.3399)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.43522154415719666
# Angle for Image embedding before normalizing: Averaging  tensor(56.3481)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5668330708330709
# Angle for Image embedding after normalizing: Averaging  tensor(53.9419)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.6038793758793759
# Angle for text embedding before normalizing: Averaging  tensor(38.0441)
# Spearman's correlation coefficient for text embedding before normalizing: 0.3548509007965118
# Angle for text embedding after normalizing: Averaging  tensor(39.0928)
# Spearman's correlation coefficient for text embedding after normalizing: 0.3487768364976368
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(68.3732)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.3361659417717169
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(66.5672)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.36510709751634185
# ---- Pair ---- mask:face::makeup:blemish
# Angle for Image embedding before normalizing: Averaging  tensor(42.1139)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.4735972172154129
# Angle for Image embedding after normalizing: Averaging  tensor(41.9873)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.4744498947139538
# Angle for Image embedding before normalizing: Averaging  tensor(28.5920)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.8511753591753592
# Angle for Image embedding after normalizing: Averaging  tensor(31.6416)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.8223969063969065
# Angle for text embedding before normalizing: Averaging  tensor(36.1818)
# Spearman's correlation coefficient for text embedding before normalizing: 0.25899616335358944
# Angle for text embedding after normalizing: Averaging  tensor(38.0039)
# Spearman's correlation coefficient for text embedding after normalizing: 0.24116780964969503
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(81.1231)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.15656131473857884
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(80.3131)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.16624788135469812
# ---- Pair ---- forward:backward::top:bottom
# Angle for Image embedding before normalizing: Averaging  tensor(43.7263)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.3730910645620901
# Angle for Image embedding after normalizing: Averaging  tensor(38.2512)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.4086822364129502
# Angle for Image embedding before normalizing: Averaging  tensor(74.6155)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.2988024228024228
# Angle for Image embedding after normalizing: Averaging  tensor(78.5001)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.22833066033066032
# Angle for text embedding before normalizing: Averaging  tensor(30.3744)
# Spearman's correlation coefficient for text embedding before normalizing: 0.46785950321008
# Angle for text embedding after normalizing: Averaging  tensor(30.6681)
# Spearman's correlation coefficient for text embedding after normalizing: 0.4620429319588926
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(71.1415)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.32378665464520967
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(69.3943)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.35246915590283345
# ---- Pair ---- fragile:damaged::elastic:stretched
# Angle for Image embedding before normalizing: Averaging  tensor(46.3744)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.27897145474988844
# Angle for Image embedding after normalizing: Averaging  tensor(43.5494)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.29868987894965726
# Angle for Image embedding before normalizing: Averaging  tensor(53.0731)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.6225745425745426
# Angle for Image embedding after normalizing: Averaging  tensor(50.1005)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.6572750252750252
# Angle for text embedding before normalizing: Averaging  tensor(35.1869)
# Spearman's correlation coefficient for text embedding before normalizing: 0.34062834383332763
# Angle for text embedding after normalizing: Averaging  tensor(36.2660)
# Spearman's correlation coefficient for text embedding after normalizing: 0.33564594276787857
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(72.5364)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.2850011150216649
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(73.7133)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.26856724564993745
# ---- Pair ---- arrhythmia:heartbeat::pimple:skin
# Angle for Image embedding before normalizing: Averaging  tensor(28.4712)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5713746588217119
# Angle for Image embedding after normalizing: Averaging  tensor(32.1212)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.5467724498174661
# Angle for Image embedding before normalizing: Averaging  tensor(41.4248)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.7381724221724223
# Angle for Image embedding after normalizing: Averaging  tensor(44.1380)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.7033899793899794
# Angle for text embedding before normalizing: Averaging  tensor(38.7947)
# Spearman's correlation coefficient for text embedding before normalizing: 0.3124754129902382
# Angle for text embedding after normalizing: Averaging  tensor(37.9028)
# Spearman's correlation coefficient for text embedding after normalizing: 0.3184223400968174
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(73.7844)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.274683789317002
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(71.4456)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.31264556478375916
# ---- Pair ---- library:book::casino:cards
# Angle for Image embedding before normalizing: Averaging  tensor(31.6812)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5664512665796912
# Angle for Image embedding after normalizing: Averaging  tensor(33.9276)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.5544863335564939
# Angle for Image embedding before normalizing: Averaging  tensor(34.9507)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.8266700746700748
# Angle for Image embedding after normalizing: Averaging  tensor(34.8381)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.8280260880260881
# Angle for text embedding before normalizing: Averaging  tensor(36.2277)
# Spearman's correlation coefficient for text embedding before normalizing: 0.33286108393128944
# Angle for text embedding after normalizing: Averaging  tensor(37.6291)
# Spearman's correlation coefficient for text embedding after normalizing: 0.32578628363145307
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(79.9050)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.19577119759770786
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(80.0163)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.1899109752739166
# ---- Pair ---- script:movie::choreography:performance
# Angle for Image embedding before normalizing: Averaging  tensor(56.6452)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.30766842906352637
# Angle for Image embedding after normalizing: Averaging  tensor(55.8673)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.3069747177590094
# Angle for Image embedding before normalizing: Averaging  tensor(49.1593)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.660988236988237
# Angle for Image embedding after normalizing: Averaging  tensor(57.0542)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.5485120285120285
# Angle for text embedding before normalizing: Averaging  tensor(34.8614)
# Spearman's correlation coefficient for text embedding before normalizing: 0.31656400919536287
# Angle for text embedding after normalizing: Averaging  tensor(35.0970)
# Spearman's correlation coefficient for text embedding after normalizing: 0.3215986241288152
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(77.5050)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.21065261042074399
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(78.4311)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.19886333648806062
# ---- Pair ---- ocean:Pacific::planet:Earth
# Angle for Image embedding before normalizing: Averaging  tensor(38.0000)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.6909023951144985
# Angle for Image embedding after normalizing: Averaging  tensor(35.3768)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.7102279636019272
# Angle for Image embedding before normalizing: Averaging  tensor(48.7804)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.6439553359553359
# Angle for Image embedding after normalizing: Averaging  tensor(52.0925)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.60999342999343
# Angle for text embedding before normalizing: Averaging  tensor(30.0649)
# Spearman's correlation coefficient for text embedding before normalizing: 0.44369673112575964
# Angle for text embedding after normalizing: Averaging  tensor(31.2863)
# Spearman's correlation coefficient for text embedding after normalizing: 0.4272112751914032
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(70.3683)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.3441484371088562
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(71.1669)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.33072455317367155
# ---- Pair ---- wash:dirty::fill:empty
# Angle for Image embedding before normalizing: Averaging  tensor(49.9771)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.22979993863082362
# Angle for Image embedding after normalizing: Averaging  tensor(43.9206)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.2920254581945732
# Angle for Image embedding before normalizing: Averaging  tensor(88.0326)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.03472981072981073
# Angle for Image embedding after normalizing: Averaging  tensor(74.4885)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.2817794097794098
# Angle for text embedding before normalizing: Averaging  tensor(31.0197)
# Spearman's correlation coefficient for text embedding before normalizing: 0.299138614229638
# Angle for text embedding after normalizing: Averaging  tensor(33.1021)
# Spearman's correlation coefficient for text embedding after normalizing: 0.281754078403772
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(70.4110)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.3147868945727632
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(70.2916)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.3170407230311223
# ---- Pair ---- hand:finger::egg:yolk
# Angle for Image embedding before normalizing: Averaging  tensor(20.8985)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.8180280538675456
# Angle for Image embedding after normalizing: Averaging  tensor(21.0820)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.8189449258133918
# Angle for Image embedding before normalizing: Averaging  tensor(34.2079)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.8132317772317773
# Angle for Image embedding after normalizing: Averaging  tensor(34.8354)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.8051599931599933
# Angle for text embedding before normalizing: Averaging  tensor(39.4026)
# Spearman's correlation coefficient for text embedding before normalizing: 0.4005593142387933
# Angle for text embedding after normalizing: Averaging  tensor(37.8959)
# Spearman's correlation coefficient for text embedding after normalizing: 0.4103650607683592
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(60.7968)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.4593543645849964
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(63.2581)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.42698991050682333
# ---- Pair ---- father:mother::mother:father
# Angle for Image embedding before normalizing: Averaging  tensor(38.7053)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.3999787925864891
# Angle for Image embedding after normalizing: Averaging  tensor(39.0688)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.3929135588686327
# Angle for Image embedding before normalizing: Averaging  tensor(56.3890)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5503685023685024
# Angle for Image embedding after normalizing: Averaging  tensor(59.8539)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.4999246999246999
# Angle for text embedding before normalizing: Averaging  tensor(41.4504)
# Spearman's correlation coefficient for text embedding before normalizing: 0.20242610307160594
# Angle for text embedding after normalizing: Averaging  tensor(40.8274)
# Spearman's correlation coefficient for text embedding after normalizing: 0.21268961501928335
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(63.6596)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.41457178753193696
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(64.6676)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.3982625501757632
# ---- Pair ---- life:biography::achievement:trophy
# Angle for Image embedding before normalizing: Averaging  tensor(43.5374)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.4638968819022442
# Angle for Image embedding after normalizing: Averaging  tensor(40.7623)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.44105751679426886
# Angle for Image embedding before normalizing: Averaging  tensor(53.4710)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.6638355158355159
# Angle for Image embedding after normalizing: Averaging  tensor(57.1688)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.609914301914302
# Angle for text embedding before normalizing: Averaging  tensor(34.8844)
# Spearman's correlation coefficient for text embedding before normalizing: 0.35490311466451513
# Angle for text embedding after normalizing: Averaging  tensor(32.5628)
# Spearman's correlation coefficient for text embedding after normalizing: 0.36208645543653656
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(78.4104)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.18272200476287123
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(78.6365)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.18339238795082466
# ---- Pair ---- fragile:unbreakable::lazy:productive
# Angle for Image embedding before normalizing: Averaging  tensor(54.7064)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.2533077127750884
# Angle for Image embedding after normalizing: Averaging  tensor(55.9543)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.24152418718027943
# Angle for Image embedding before normalizing: Averaging  tensor(56.9925)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5798051918051919
# Angle for Image embedding after normalizing: Averaging  tensor(59.7464)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.5436992796992797
# Angle for text embedding before normalizing: Averaging  tensor(30.5743)
# Spearman's correlation coefficient for text embedding before normalizing: 0.32421396670901
# Angle for text embedding after normalizing: Averaging  tensor(33.8904)
# Spearman's correlation coefficient for text embedding after normalizing: 0.3027234896602236
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(78.4185)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.17861478655413218
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(78.2227)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.17003294724104373
# ---- Pair ---- acceleration:speed::dim:light
# Angle for Image embedding before normalizing: Averaging  tensor(25.7356)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.661296416698138
# Angle for Image embedding after normalizing: Averaging  tensor(32.6607)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.590389179283826
# Angle for Image embedding before normalizing: Averaging  tensor(29.8681)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.8554868554868555
# Angle for Image embedding after normalizing: Averaging  tensor(32.4489)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.8295264735264735
# Angle for text embedding before normalizing: Averaging  tensor(30.5466)
# Spearman's correlation coefficient for text embedding before normalizing: 0.38009264027649026
# Angle for text embedding after normalizing: Averaging  tensor(31.6687)
# Spearman's correlation coefficient for text embedding after normalizing: 0.3698980613634543
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(67.8116)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.34840945841641646
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(67.6165)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.3516356799115213
# ---- Pair ---- fire:hot::villain:evil
# Angle for Image embedding before normalizing: Averaging  tensor(62.9217)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.1530819414403589
# Angle for Image embedding after normalizing: Averaging  tensor(48.5791)
# ...
# Angle for text embedding after normalizing: Averaging  tensor(43.4623)
# Spearman's correlation coefficient for text embedding after normalizing: 0.13898231952598392
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(77.8349)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.20831513396698467
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(75.9421)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.23724536282071396
# ---- Pair ---- sword:knife::ladder:stairs
# Angle for Image embedding before normalizing: Averaging  tensor(42.3740)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.2970792956992939
# Angle for Image embedding after normalizing: Averaging  tensor(42.8251)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.29050857380322953
# Angle for Image embedding before normalizing: Averaging  tensor(54.9215)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.6175302775302777
# Angle for Image embedding after normalizing: Averaging  tensor(54.1823)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.6249955809955811
# Angle for text embedding before normalizing: Averaging  tensor(37.8038)
# Spearman's correlation coefficient for text embedding before normalizing: 0.40644669607809475
# Angle for text embedding after normalizing: Averaging  tensor(37.2955)
# Spearman's correlation coefficient for text embedding after normalizing: 0.4233857152870761
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(71.2413)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.3373130328318053
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(71.6276)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.3286247373892442
# ---- Pair ---- tool:hammer::tool:screwdriver
# Angle for Image embedding before normalizing: Averaging  tensor(27.5675)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.7249847292317552
# Angle for Image embedding after normalizing: Averaging  tensor(27.5675)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.7249847292317552
# Angle for Image embedding before normalizing: Averaging  tensor(38.9973)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.7185789225789226
# Angle for Image embedding after normalizing: Averaging  tensor(38.9973)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.7185789225789226
# Angle for text embedding before normalizing: Averaging  tensor(33.0651)
# Spearman's correlation coefficient for text embedding before normalizing: 0.3795696969306829
# Angle for text embedding after normalizing: Averaging  tensor(33.0651)
# Spearman's correlation coefficient for text embedding after normalizing: 0.3795696969306829
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(67.4716)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.40062334510763975
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(67.4716)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.4005997218395896
# ---- Pair ---- girl:woman::baby:adult
# Angle for Image embedding before normalizing: Averaging  tensor(36.0793)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.34522057140568313
# Angle for Image embedding after normalizing: Averaging  tensor(37.5504)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.31835394350602536
# Angle for Image embedding before normalizing: Averaging  tensor(50.3802)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.6733918174119928
# Angle for Image embedding after normalizing: Averaging  tensor(48.1222)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.7015995557043544
# Angle for text embedding before normalizing: Averaging  tensor(37.0633)
# Spearman's correlation coefficient for text embedding before normalizing: 0.18618535493986108
# Angle for text embedding after normalizing: Averaging  tensor(37.4969)
# Spearman's correlation coefficient for text embedding after normalizing: 0.18300388528398623
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(80.1770)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.17404078006464935
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(79.4407)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.18680268969257077
# ---- Pair ---- hot:cold::full:empty
# Angle for Image embedding before normalizing: Averaging  tensor(44.6049)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.30490779960746617
# Angle for Image embedding after normalizing: Averaging  tensor(46.7454)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.29360001029972194
# Angle for Image embedding before normalizing: Averaging  tensor(77.2997)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.2819078099078099
# Angle for Image embedding after normalizing: Averaging  tensor(76.0537)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.3062855462855463
# Angle for text embedding before normalizing: Averaging  tensor(35.1916)
# Spearman's correlation coefficient for text embedding before normalizing: 0.262625563623671
# Angle for text embedding after normalizing: Averaging  tensor(34.9965)
# Spearman's correlation coefficient for text embedding after normalizing: 0.26693928743090606
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(79.5250)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.19206623938057807
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(78.8389)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.19456952990760443
# ---- Pair ---- freezing:warm::gigantic:short
# Angle for Image embedding before normalizing: Averaging  tensor(45.9313)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.23719061495061858
# Angle for Image embedding after normalizing: Averaging  tensor(48.4624)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.21771716677538594
# Angle for Image embedding before normalizing: Averaging  tensor(56.9835)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5473323673323673
# Angle for Image embedding after normalizing: Averaging  tensor(62.4779)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.45860483060483065
# Angle for text embedding before normalizing: Averaging  tensor(40.0147)
# Spearman's correlation coefficient for text embedding before normalizing: 0.2657932645540793
# Angle for text embedding after normalizing: Averaging  tensor(40.4407)
# Spearman's correlation coefficient for text embedding after normalizing: 0.2597757950813106
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(85.5450)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.05090534176044454
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(84.7968)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.0662411863998839
# ---- Pair ---- heart:beat::fire:burn
# Angle for Image embedding before normalizing: Averaging  tensor(27.5521)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.7101969392659732
# Angle for Image embedding after normalizing: Averaging  tensor(26.6263)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.7124990880454561
# Angle for Image embedding before normalizing: Averaging  tensor(51.7128)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5613397893397895
# Angle for Image embedding after normalizing: Averaging  tensor(45.4126)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.6610050250050251
# Angle for text embedding before normalizing: Averaging  tensor(28.3887)
# Spearman's correlation coefficient for text embedding before normalizing: 0.40622675409986153
# Angle for text embedding after normalizing: Averaging  tensor(30.0299)
# Spearman's correlation coefficient for text embedding after normalizing: 0.38718469618681406
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(75.8131)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.2498303305454403
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(76.2838)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.2407333805442385
# ---- Pair ---- army:soldiers::library:books
# Angle for Image embedding before normalizing: Averaging  tensor(30.8651)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.6671508072407045
# Angle for Image embedding after normalizing: Averaging  tensor(31.6848)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.6646107456140351
# Angle for Image embedding before normalizing: Averaging  tensor(56.1976)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.5635490755490756
# Angle for Image embedding after normalizing: Averaging  tensor(55.5506)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.5772536532536533
# Angle for text embedding before normalizing: Averaging  tensor(33.5655)
# Spearman's correlation coefficient for text embedding before normalizing: 0.45808317168492
# Angle for text embedding after normalizing: Averaging  tensor(31.9926)
# Spearman's correlation coefficient for text embedding after normalizing: 0.4730399414632472
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(65.7670)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.4151808547023625
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(65.7051)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.41677767761928136
# ---- Pair ---- discipline:abuse::discard:litter
# Angle for Image embedding before normalizing: Averaging  tensor(45.2283)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.29153577436742545
# Angle for Image embedding after normalizing: Averaging  tensor(43.9514)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.3076158575662902
# Angle for Image embedding before normalizing: Averaging  tensor(57.1671)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.552917040917041
# Angle for Image embedding after normalizing: Averaging  tensor(56.9284)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.5550373350373351
# Angle for text embedding before normalizing: Averaging  tensor(39.2966)
# Spearman's correlation coefficient for text embedding before normalizing: 0.19630438467744704
# Angle for text embedding after normalizing: Averaging  tensor(40.3351)
# Spearman's correlation coefficient for text embedding after normalizing: 0.1985792642279214
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(76.6224)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.21313008954300677
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(76.8683)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.21114308699290535
# ---- Pair ---- snacks:chips::cutlery:forks
# Angle for Image embedding before normalizing: Averaging  tensor(34.6131)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.6288734822215356
# Angle for Image embedding after normalizing: Averaging  tensor(36.0217)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.6105900453187764
# Angle for Image embedding before normalizing: Averaging  tensor(45.5221)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.6555060075060075
# Angle for Image embedding after normalizing: Averaging  tensor(46.4228)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.6452149892149892
# Angle for text embedding before normalizing: Averaging  tensor(39.5311)
# Spearman's correlation coefficient for text embedding before normalizing: 0.4944579985923713
# Angle for text embedding after normalizing: Averaging  tensor(36.9750)
# Spearman's correlation coefficient for text embedding after normalizing: 0.5134754694956569
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(68.0266)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.32890048463180366
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(68.9677)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.3112300709492657
# ---- Pair ---- fruit:apple::furniture:chair
# Angle for Image embedding before normalizing: Averaging  tensor(29.6801)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.6435188463453153
# Angle for Image embedding after normalizing: Averaging  tensor(29.7307)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.648245900138474
# Angle for Image embedding before normalizing: Averaging  tensor(35.1271)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.8151695631695632
# Angle for Image embedding after normalizing: Averaging  tensor(34.8350)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.8204633324633325
# Angle for text embedding before normalizing: Averaging  tensor(38.9087)
# Spearman's correlation coefficient for text embedding before normalizing: 0.3640248952861606
# Angle for text embedding after normalizing: Averaging  tensor(40.1263)
# Spearman's correlation coefficient for text embedding after normalizing: 0.35223663110401576
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(77.7580)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.20128695506984684
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(77.5797)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.20437966910367136
# ---- Pair ---- hotel:lobby::hill:top
# Angle for Image embedding before normalizing: Averaging  tensor(27.1098)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.6782676225380804
# Angle for Image embedding after normalizing: Averaging  tensor(29.9094)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.6522519733981071
# Angle for Image embedding before normalizing: Averaging  tensor(42.9230)
# Spearman's correlation coefficient for Image embedding before normalizing: 0.6852565332565334
# Angle for Image embedding after normalizing: Averaging  tensor(44.2111)
# Spearman's correlation coefficient for Image embedding after normalizing: 0.6610541410541411
# Angle for text embedding before normalizing: Averaging  tensor(40.1815)
# Spearman's correlation coefficient for text embedding before normalizing: 0.36920569116856067
# Angle for text embedding after normalizing: Averaging  tensor(38.7636)
# Spearman's correlation coefficient for text embedding after normalizing: 0.3792219919089962
# Word2Vec Angle for text embedding before normalizing: Averaging  tensor(86.3051)
# Word2Vec Spearman's correlation coefficient for text embedding before normalizing: 0.0260853584256246
# Word2Vec Angle for text embedding after normalizing: Averaging  tensor(86.2712)
# Word2Vec Spearman's correlation coefficient for text embedding after normalizing: 0.028432702419448782
